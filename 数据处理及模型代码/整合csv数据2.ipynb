# %%
import pandas as pd
import os
import csv

# %%
# reader = csv.DictReader(open('评论/处理完/出山评论3.csv',encoding='utf-8-sig'))
# header = reader.fieldnames
# header
# Out:
# ['name', 'id', 'comment', 'time', 'positive_prob', 'sentiment']

# %%
# reader = csv.DictReader(open('评论/处理完/DanceMonkey评论1.csv'))
# header = reader.fieldnames
# with open('评论/处理完/test.csv', 'a') as csv_file:
#     writer = csv.DictWriter(csv_file, fieldnames=header)
#     writer.writerows(reader)

# %%
outputpath='评论/处理完/test2.csv'

# %%
dataset=pd.read_csv("评论/处理完/嚣张评论1.csv")
dataset.to_csv(outputpath,sep=',',mode='a',encoding='utf-8-sig',index=False,header=False)

# %%
outputpath='评论/处理完/test3.csv'
dataset=pd.read_csv("评论/处理完/test2.csv",header=None)
dataset.columns = ['name', 'id', 'comment', 'time','positive_prob','sentiment']
dataset
# Out:
#                name          id  \
# 0            Retry-   561005958
# 1             0959D   356748512
# 2            shang毛  1434868508
# 3              紫金孤枭  1393196925
# 4            shang毛  1434868508
# 5              景林zz   135883673
# 6          白色风车aacs  1981968060
# 7          你渴吗丶灌你喝水   564346359
# 8              东城以旧   558822618
# 9               覃湘呀  1406686523
# 10           丶孑丶然一身  1496964474
# 11           AAA王禹顺  1709176933
# 12         Mr_dense   416904612
# 13             仙男柠七  1908161515
# 14         shawty小禁   376458500
# 15         宗政永山1810  1625495980
# 16           荒漠里的孤狼   312432101
# 17          常贵华1911  2044735852
# 18         -Ctrl-C-    64318332
# 19           jffcvv   128723577
# 20           南枕zinc   450484375
# 21            CC丶带感   437404191
# 22        可爱要加糖1910  1898524630
# 23           EririD   481272565
# 24              b宙问  1830603396
# 25          walyz颜乐   340582057
# 26        渣渣Joekwan   310228155
# 27           遇不见的路人   422747957
# ...

# %%
dataset.to_csv(outputpath,sep=',',encoding='utf-8-sig',index=False)
