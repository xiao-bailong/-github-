# %%
import pandas as pd

# %%
dataset=pd.read_csv("评论/处理完/test3.csv",encoding='utf-8-sig')
dataset['sentiment'].value_counts()
#0消极，1中肯，2积极
# Out:
# 2      26179
# 0      18751
# 1      10498
#         1321
# 2.0     1013
# 0.0      662
# 1.0      316
# Name: sentiment, dtype: int64

# %%
dataset0=dataset.loc[dataset['sentiment'].isin(['0','0.0'])]
dataset0
# Out:
#                   name          id  \
# 0               Retry-   561005958
# 3                 紫金孤枭  1393196925
# 4               shang毛  1434868508
# 10              丶孑丶然一身  1496964474
# 11              AAA王禹顺  1709176933
# 13                仙男柠七  1908161515
# 14            shawty小禁   376458500
# 15            宗政永山1810  1625495980
# 17             常贵华1911  2044735852
# 19              jffcvv   128723577
# 20              南枕zinc   450484375
# 22           可爱要加糖1910  1898524630
# 24                 b宙问  1830603396
# 27              遇不见的路人   422747957
# 28                 林宇晟  1953164095
# 30                 澄澄b   288964797
# 34               Ycdi_   415545007
# 35              病人快不行了   132316175
# 37               嘻嘻嘻卧槽  1402998621
# 38             工号jo527  1653722798
# 43            昏睡的小天爱做梦   426436387
# 46                  亓肀   304872602
# 48                 香丘下   388701732
# 49                惘昕殇汐  1570926298
# 57                 祢小媽   413124678
# ...

# %%
dataset0.to_csv('评论/处理完/negative.csv',sep=',',encoding='utf-8-sig',index=False)

# %%
dataset1=dataset.loc[dataset['sentiment'].isin(['1','1.0'])]
dataset1
# Out:
#                        name          id  \
# 6                  白色风车aacs  1981968060
# 9                       覃湘呀  1406686523
# 29                    Y丶老年人  1360195158
# 33                 此生不悔入网易云  1698293316
# 42                   alan超人    45972773
# 52     Funny-Clown-like-you   398770651
# 54               Masker1209   316689504
# 63                   芒果味的阿雅    55400710
# 68                   G-7317   268092007
# 69            AYTZ147258369  1312403499
# 81                   454醒目没  1537339992
# 88                 Amoronic  1447171652
# 89                   十一祝你快乐   610998174
# 94              bingbinging   300977941
# 96                 jujulu87  1488027410
# 107                      穹嚄  1773341725
# 113                    裳虹殇衣   507566940
# 117               喇叭正露丸Plus  1553479686
# 125                      似仕  1581905183
# 127              Shhusnnxjc   300012722
# 128                  孫立健720  1294520446
# 132                  Wor丶泡面  1779781978
# ...

# %%
dataset1.to_csv('评论/处理完/relevant.csv',sep=',',encoding='utf-8-sig',index=False)

# %%
dataset2=dataset.loc[dataset['sentiment'].isin(['2','2.0'])]
dataset2
# Out:
#                  name          id  \
# 1               0959D   356748512
# 2              shang毛  1434868508
# 7            你渴吗丶灌你喝水   564346359
# 8                东城以旧   558822618
# 12           Mr_dense   416904612
# 18           -Ctrl-C-    64318332
# 21              CC丶带感   437404191
# 25            walyz颜乐   340582057
# 32                林宇晟  1953164095
# 36              嘻嘻嘻卧槽  1402998621
# 39              注意小菊花  1510633457
# 41        Chelsea0621   293738806
# 44               沈奕星-   528297870
# 47               岛田川樱  1822510913
# 51        老肆说老叁的老贰老大了   386980019
# 53       Neuropathywj   319908223
# 55            CLxhwzy   479069711
# 56            元方芳你怎么看  1784525010
# 58             掉了根眼睫毛   280916677
# 60        深海里的鱼180726  1533101868
# 61            12345南南   312876316
# 62            未知帐号已注销   338020204
# 64              感化孤儿院   421692607
# 65              玉腿毛绒绒  1424014717
# 74            想只听SQ品质   107927330
# 75            呵呵哒6312   251192091
# ...

# %%
dataset2.to_csv('评论/处理完/positive.csv',sep=',',encoding='utf-8-sig',index=False)
